# %% [markdown]
# # Lección 1 · Práctica: Introducción a Python
#
# **Cómo funciona:** ejecuta cada celda con `Shift + Enter`, de arriba abajo. En los ejercicios, sustituye el valor `None` por tu respuesta y ejecuta: si ves ✅, está bien; si ves `AssertionError`, revisa tu respuesta.
#
# Teoría completa: [README de la lección](https://github.com/GeckCore/VScode/blob/main/leccion01-introduccion/README.md)

# %% [markdown]
# ## Calentamiento: tu primer print
# Ejecuta esta celda tal cual está (Shift + Enter).

# %%
print("Hola, mundo")
print("Estoy aprendiendo Python")
print("2 + 2 =", 2 + 2)

# %% [markdown]
# ### Ejercicio 1 · Tu nombre
#
# Modifica la celda para que imprima **tu nombre** (el texto que quieras, entre comillas). El assert comprueba que has cambiado algo.

# %%
# === EJERCICIO 1 ===
mi_nombre = None  # ← Pon tu nombre entre comillas, por ejemplo "Lucía"

assert isinstance(mi_nombre, str) and len(mi_nombre) > 0, "Pon tu nombre como texto entre comillas"
print("Hola, me llamo", mi_nombre)
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Print calculando
#
# Usa `print()` para mostrar el resultado de multiplicar 7 por 8 **sin escribir el 56 a mano**: deja que Python calcule.

# %%
# === EJERCICIO 2 ===
resultado = None  # ← Sustituye por la operación 7 * 8

assert resultado == 56, "resultado debe valer 7 * 8 calculado por Python"
print("7 x 8 =", resultado)
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Varias cosas a la vez
#
# Completa el `print` para que muestre el texto `"Me gusta"` y la variable `comida` en una sola línea, separados por un espacio (pista: sepáralos con una coma).

# %%
# === EJERCICIO 3 ===
comida = "pizza"
frase_impresa = None  # ← Esto es solo para el test: escribe aquí la frase completa "Me gusta pizza"

# Escribe tu print aquí debajo:


assert frase_impresa == "Me gusta pizza"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · Comentarios
#
# Añade un comentario en la primera línea de la celda que explique qué hace el código, y luego ejecútala. El test comprueba que la variable tiene el valor esperado.

# %%
# === EJERCICIO 4 ===
# ← Escribe tu comentario aquí
horas_dia = 24
dias_semana = 7
horas_semana = horas_dia * dias_semana
print("Una semana tiene", horas_semana, "horas")

assert horas_semana == 168
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · Input básico
#
# Ejecuta la celda: te pedirá tu color favorito y te saludará con él. No hay assert, solo experimenta.

# %%
# === EJERCICIO 5 ===
color = input("¿Cuál es tu color favorito? ")
print("¡El", color, "es un color genial!")

# %% [markdown]
# ### Ejercicio 6 · La trampa de input
#
# Ejecuta esta celda y escribe tu edad. Verás un error: léelo con calma antes de seguir. ¿Por qué falla?

# %%
# === EJERCICIO 6 === (¡este ejercicio FALLA a propósito!)
edad_texto = input("¿Cuántos años tienes? ")
print("El año que viene tendrás", edad_texto + 1)  # ← TypeError: ¿por qué?

# %% [markdown]
# ### Ejercicio 7 · Arregla el ejercicio 6
#
# `input()` devuelve texto. Usa `int()` para convertirlo a número y haz que funcione.

# %%
# === EJERCICIO 7 ===
edad = int(input("¿Cuántos años tienes? "))  # ← int() convierte el texto a número
edad_proxima = edad + 1
print("El año que viene tendrás", edad_proxima)

assert isinstance(edad_proxima, int)
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · Caza el error
#
# Esta celda tiene **dos errores**. Corrígela para que imprima tu ciudad y tu año de nacimiento. Pista: lee el mensaje de error, línea por línea.

# %%
# === EJERCICIO 8 === (corrige los 2 errores)
ciudad = "Las Palmas"
año_nacimiento = 2008
prin("Vivo en", ciudad)
print("Nací en", año_nacimiento

# %% [markdown]
# ### Ejercicio 9 · Mini calculadora de edad
#
# Pide al usuario su año de nacimiento con `input()`, conviértelo a número y calcula cuántos años cumplirá en 2030.

# %%
# === EJERCICIO 9 ===
nacimiento = None  # ← int(input(...)) aquí

edad_2030 = None  # ← calcula 2030 - nacimiento

assert isinstance(nacimiento, int), "nacimiento debe ser un número entero"
assert edad_2030 == 2030 - nacimiento
print("En 2030 cumplirás", edad_2030, "años")
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 10 · Reto final: presentación completa
#
# Escribe un programa que:
# 1. Pregunte el nombre del usuario.
# 2. Pregunte su edad.
# 3. Imprima algo como: `Hola Ana, tienes 20 años y en 2050 tendrás 44.`
#
# Pista: guarda cada dato en una variable y usa un solo `print` con varias partes separadas por comas.

# %%
# === EJERCICIO 10 ===
# Escribe tu solución aquí:

# %% [markdown]
# ---
# ## 🔑 Soluciones
#
# **Intenta cada ejercicio al menos 15 minutos antes de mirar.** Las soluciones sirven para comprobar, no para copiar.

# %%
# SOLUCIONES LECCIÓN 1
# EJ 3:  print("Me gusta", comida)
# EJ 8:  print estaba mal escrito (prin) y faltaba cerrar el paréntesis:
#        print("Vivo en", ciudad)
#        print("Nací en", año_nacimiento)
# EJ 9:  nacimiento = int(input("¿En qué año naciste? "))
#        edad_2030 = 2030 - nacimiento
# EJ 10:
#   nombre = input("¿Cómo te llamas? ")
#   edad = int(input("¿Cuántos años tienes? "))
#   print("Hola", nombre + ", tienes", edad, "años y en 2050 tendrás", edad + (2050 - 2026))
