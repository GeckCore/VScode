# %% [markdown]
# # Lección 2 · Práctica: Variables y tipos
#
# Ejecuta las celdas en orden con `Shift + Enter`. Sustituye los `None` por tus respuestas. Teoría: [README de la lección](https://github.com/GeckCore/VScode/blob/main/leccion02-variables-tipos/README.md)

# %% [markdown]
# ## Calentamiento: juega con los tipos
#
# Ejecuta y observa la salida de cada línea.

# %%
print(type(42))
print(type(42.0))
print(type("42"))
print(type(True))
print(type(3 > 1))

# %% [markdown]
# ### Ejercicio 1 · Crea tus variables
#
# Crea tres variables: tu nombre (str), tu edad (int) y tu altura en metros (float).

# %%
# === EJERCICIO 1 ===
nombre = None
edad = None
altura = None

assert isinstance(nombre, str), "nombre debe ser texto entre comillas"
assert isinstance(edad, int) and not isinstance(edad, bool), "edad debe ser un número entero (sin comillas)"
assert isinstance(altura, float), "altura debe ser un float, por ejemplo 1.75"
print(f"{nombre}, {edad} años, {altura} m")
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Reasignar
#
# Crea una variable `puntos` que valga 50. Luego, en otra línea, haz que valga lo que valía más 25 (sin escribir 75 directamente).

# %%
# === EJERCICIO 2 ===
puntos = 50
# ← tu línea aquí

assert puntos == 75, "puntos debe valer 75 usando puntos = puntos + ..."
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Concatenar
#
# Une las variables `saludo` y `destino` con un espacio en medio para formar `"Hola Gran Canaria"`.

# %%
# === EJERCICIO 3 ===
saludo = "Hola"
destino = "Gran Canaria"
mensaje = None  # ← concatena aquí

assert mensaje == "Hola Gran Canaria"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · Conversión
#
# Tienes el precio como **texto**. Conviértelo a `float`, súmale el 7% de IVA (multiplica por 1.07) y redondea a 2 decimales con `round(x, 2)`.

# %%
# === EJERCICIO 4 ===
precio_texto = "19.95"
precio_final = None  # ← float, +7% IVA, round(..., 2)

assert precio_final == 21.35, f"Esperaba 21.35 y salió {precio_final}"
print(f"Precio con IVA: {precio_final} €")
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · f-strings
#
# Construye con un f-string la frase exacta: `En 2026 tengo 18 años y mido 1.75 metros.`

# %%
# === EJERCICIO 5 ===
año = 2026
edad = 18
altura = 1.75
frase = None  # ← f-string aquí

assert frase == "En 2026 tengo 18 años y mido 1.75 metros.", f"Salió: {frase}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 6 · Formato de decimales
#
# Muestra el número pi con exactamente 4 decimales usando un f-string. Debe salir el texto `3.1416`.

# %%
# === EJERCICIO 6 ===
import math
pi_texto = None  # ← f-string con formato :.4f sobre math.pi

assert pi_texto == "3.1416", f"Salió: {pi_texto}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 7 · La trampa del input
#
# El usuario escribe dos números como texto. Súmalos correctamente (debe dar 15, no "78").

# %%
# === EJERCICIO 7 ===
a = "7"   # simula un input()
b = "8"
suma = None  # ← convierte y suma

assert suma == 15, f"Salió {suma}: recuerda convertir el texto a número"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · Booleanos
#
# Guarda en `es_mayor` el resultado de comparar si `edad` es mayor o igual que 18 (solo guarda la comparación, sin if).

# %%
# === EJERCICIO 8 ===
edad = 21
es_mayor = None  # ← una comparación: edad ... 18

assert es_mayor is True, "es_mayor debe ser el booleano True (resultado de la comparación)"
print(type(es_mayor))
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 9 · Intercambio de variables
#
# Intercambia los valores de `x` e `y` de modo que `x` valga 2 e `y` valga 1. Pista elegante: en Python se puede hacer en una sola línea con `x, y = ...`.

# %%
# === EJERCICIO 9 ===
x = 1
y = 2
# ← tu intercambio aquí

assert x == 2 and y == 1
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 10 · Reto: calculadora de propina
#
# Pide con `input()` el total de la cuenta (float) y el porcentaje de propina (float, por ejemplo 10 para 10%). Calcula la propina y el total final, y muéstralos con un f-string con 2 decimales.

# %%
# === EJERCICIO 10 ===
# Escribe tu solución aquí:

# %% [markdown]
# ---
# ## 🔑 Soluciones
#
# Inténtalo primero. Mira esto solo para comprobar.

# %%
# SOLUCIONES LECCIÓN 2
# EJ 2: puntos = puntos + 25   (o puntos += 25)
# EJ 3: mensaje = saludo + " " + destino
# EJ 4: precio_final = round(float(precio_texto) * 1.07, 2)
# EJ 5: frase = f"En {año} tengo {edad} años y mido {altura} metros."
# EJ 6: pi_texto = f"{math.pi:.4f}"
# EJ 7: suma = int(a) + int(b)
# EJ 8: es_mayor = edad >= 18
# EJ 9: x, y = y, x
# EJ 10:
#   cuenta = float(input("Total de la cuenta: "))
#   porcentaje = float(input("Propina (%): "))
#   propina = cuenta * porcentaje / 100
#   total = cuenta + propina
#   print(f"Propina: {propina:.2f} € — Total: {total:.2f} €")
