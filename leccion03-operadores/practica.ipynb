# %% [markdown]
# # Lección 3 · Práctica: Operadores
#
# Ejecuta en orden con `Shift + Enter`. Teoría: [README](https://github.com/GeckCore/VScode/blob/main/leccion03-operadores/README.md)

# %% [markdown]
# ## Calentamiento: predice antes de ejecutar
#
# Antes de ejecutar la celda, escribe en un papel qué crees que imprimirá cada línea. Luego comprueba.

# %%
print(17 / 5)
print(17 // 5)
print(17 % 5)
print(2 + 3 * 4)
print((2 + 3) * 4)
print(2 ** 8)

# %% [markdown]
# ### Ejercicio 1 · Par o impar
#
# Guarda en `es_par` un booleano que sea `True` si `numero` es par. Pista: usa `%`.

# %%
# === EJERCICIO 1 ===
numero = 42
es_par = None  # ← True si numero es par

assert es_par is True
numero = 7
# tu fórmula debe seguir funcionando con cualquier número:
assert (numero % 2 == 0) is False  # comprobación extra
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Horas y minutos
#
# Convierte `minutos_totales` en horas completas y minutos restantes usando `//` y `%`.

# %%
# === EJERCICIO 2 ===
minutos_totales = 200
horas = None      # ← cociente entero
minutos = None    # ← resto

assert horas == 3 and minutos == 20, f"Salió {horas} h {minutos} min"
print(f"{minutos_totales} minutos son {horas} h y {minutos} min")
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Divisible entre 3 y 5
#
# Guarda en `fizzbuzz` un booleano: `True` si `n` es divisible entre 3 **y** entre 5 a la vez.

# %%
# === EJERCICIO 3 ===
n = 30
fizzbuzz = None

assert fizzbuzz is True
n = 10
# con n=10 tu expresión debería dar False; verifícalo mentalmente
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · Comparaciones
#
# Sin ejecutar, asigna a cada variable el booleano que crees que produce la comparación. Luego ejecuta para comprobar.

# %%
# === EJERCICIO 4 ===
r1 = None  # ¿Qué vale?  10 > 5
r2 = None  # ¿Qué vale?  3 == "3"
r3 = None  # ¿Qué vale?  "hola" == "Hola"
r4 = None  # ¿Qué vale?  7 != 7

assert r1 is True
assert r2 is False, "Un número nunca es igual a un texto, aunque se parezcan"
assert r3 is False, "Python distingue mayúsculas de minúsculas"
assert r4 is False
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · Lógica con and/or
#
# Un cine da descuento si el cliente tiene menos de 12 años **o** más de 65. Escribe la expresión booleana en `tiene_descuento` para una persona de `edad`.

# %%
# === EJERCICIO 5 ===
edad = 70
tiene_descuento = None  # ← edad < 12 ... edad > 65

assert tiene_descuento is True
edad = 30
tiene_descuento2 = None  # ← misma expresión, debe dar False
assert tiene_descuento2 is False
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 6 · not
#
# Un parque acuático deja pasar a quienes **no** están en la lista de prohibidos. `en_lista_negra` es False: guarda en `puede_entrar` la negación correcta.

# %%
# === EJERCICIO 6 ===
en_lista_negra = False
puede_entrar = None  # ← usa not

assert puede_entrar is True
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 7 · Precedencia
#
# Añade paréntesis a la expresión para que el resultado sea 36 (ahora mismo da 22).

# %%
# === EJERCICIO 7 ===
resultado = 4 + 5 * 4  # ← pon paréntesis para que dé 36

assert resultado == 36, f"Salió {resultado}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · Año bisiesto
#
# Un año es bisiesto si es divisible entre 4 **y** (no es divisible entre 100 **o** sí es divisible entre 400). Ejemplo: 2000 bisiesto, 1900 no, 2024 sí. Escribe la expresión en `es_bisiesto` para el año `a`.

# %%
# === EJERCICIO 8 ===
a = 1900
es_bisiesto = None

assert es_bisiesto is False
a = 2000
es_bisiesto2 = None  # ← debe dar True
assert es_bisiesto2 is True
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 9 · Última cifra
#
# Guarda en `ultima` la última cifra de `n` usando operadores. Pista: ¿qué resto deja dividir entre 10?

# %%
# === EJERCICIO 9 ===
n = 12347
ultima = None

assert ultima == 7
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 10 · Reto: cambio exacto
#
# Tienes `cantidad` céntimos. Calcula cuántas monedas de 50 céntimos entran (`monedas50`) y cuántos céntimos sobran (`sobran`), usando solo `//` y `%`.

# %%
# === EJERCICIO 10 ===
cantidad = 185
monedas50 = None
sobran = None

assert monedas50 == 3 and sobran == 35
print(f"{monedas50} monedas de 50 cts y sobran {sobran} cts")
print("✅ ¡Correcto!")

# %% [markdown]
# ---
# ## 🔑 Soluciones

# %%
# SOLUCIONES LECCIÓN 3
# EJ 1: es_par = numero % 2 == 0
# EJ 2: horas = minutos_totales // 60 ; minutos = minutos_totales % 60
# EJ 3: fizzbuzz = n % 3 == 0 and n % 5 == 0
# EJ 5: tiene_descuento = edad < 12 or edad > 65
# EJ 6: puede_entrar = not en_lista_negra
# EJ 7: resultado = (4 + 5) * 4
# EJ 8: es_bisiesto = a % 4 == 0 and (a % 100 != 0 or a % 400 == 0)
# EJ 9: ultima = n % 10
# EJ 10: monedas50 = cantidad // 50 ; sobran = cantidad % 50
