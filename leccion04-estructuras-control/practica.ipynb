# %% [markdown]
# # Lección 4 · Práctica: Estructuras de control
#
# Teoría: [README](https://github.com/GeckCore/VScode/blob/main/leccion04-estructuras-control/README.md)

# %% [markdown]
# ## Calentamiento: if/else y bucles
#
# Ejecuta y experimenta cambiando los valores.

# %%
temperatura = 22
if temperatura > 30:
    print("Hace mucho calor")
elif temperatura > 20:
    print("Temperatura agradable")
else:
    print("Hace fresquito")

for i in range(3):
    print(f"Vuelta {i}")

# %% [markdown]
# ### Ejercicio 1 · Mayor de edad
#
# Completa el if para que `mensaje` sea `"adulto"` si `edad` es 18 o más, y `"menor"` en caso contrario.

# %%
# === EJERCICIO 1 ===
edad = 15
mensaje = None
# ← tu if/else aquí

assert mensaje == "menor"
edad = 40
# vuelve a aplicar tu lógica (puedes copiar el if de arriba)

assert mensaje == "adulto"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Notas
#
# Convierte `nota` (0-10) en calificación: `"sobresaliente"` (9+), `"notable"` (7-8), `"aprobado"` (5-6) o `"suspenso"` (<5). Cuida el orden de los elif.

# %%
# === EJERCICIO 2 ===
nota = 8
calificacion = None
# ← tu if/elif/else aquí

assert calificacion == "notable", f"Salió: {calificacion}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Suma con for
#
# Suma todos los números del 1 al 50 usando un `for` con `range` y el patrón acumulador.

# %%
# === EJERCICIO 3 ===
total = 0
# ← tu bucle aquí

assert total == 1275, f"Salió {total}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · Cuenta atrás con while
#
# Imprime los números del 10 al 1 (ambos incluidos) usando un `while`. Guarda el último número impreso en `ultimo`. ¡No olvides actualizar la variable!

# %%
# === EJERCICIO 4 ===
n = 10
ultimo = None
# ← tu while aquí (imprime cada n y guarda el último)

assert ultimo == 1
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · Contador con condición
#
# Cuenta cuántos números entre 1 y 100 son múltiplos de 7 (patrón contador).

# %%
# === EJERCICIO 5 ===
multiplos7 = 0
# ← tu bucle aquí

assert multiplos7 == 14, f"Salió {multiplos7}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 6 · FizzBuzz
#
# El clásico de las entrevistas: recorre los números del 1 al 20. Para múltiplos de 3 imprime `"Fizz"`, de 5 `"Buzz"`, de ambos `"FizzBuzz"`, y si no, el número. ¡Recuerda comprobar primero el caso de ambos!

# %%
# === EJERCICIO 6 ===
# Escribe tu bucle aquí:

# %% [markdown]
# ### Ejercicio 7 · break
#
# Recorre los números del 1 al 100 y para (con `break`) en el primero que sea divisible entre 7 **y** entre 11. Guárdalo en `encontrado`.

# %%
# === EJERCICIO 7 ===
encontrado = None
# ← tu bucle con break aquí

assert encontrado == 77
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · continue
#
# Suma los números del 1 al 30 **saltándote** los múltiplos de 4 (usa `continue`).

# %%
# === EJERCICIO 8 ===
suma = 0
# ← tu bucle con continue aquí

assert suma == 353, f"Salió {suma}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 9 · Triángulo de asteriscos
#
# Imprime este triángulo usando bucles (puedes usar `"*" * n` o bucles anidados):
# ```
# *
# **
# ***
# ****
# *****
# ```

# %%
# === EJERCICIO 9 ===
# Escribe tu código aquí:

# %% [markdown]
# ### Ejercicio 10 · Reto: juego de adivinanza
#
# Programa el juego: hay un número secreto (18). Pide al usuario números con `input()` hasta que acierte. En cada fallo dile si el secreto es mayor o menor. Cuenta los intentos y felicítalo al final.

# %%
# === EJERCICIO 10 ===
secreto = 18
# Escribe tu juego aquí:

# %% [markdown]
# ---
# ## 🔑 Soluciones

# %%
# SOLUCIONES LECCIÓN 4
# EJ 1:
#   if edad >= 18:
#       mensaje = "adulto"
#   else:
#       mensaje = "menor"
# EJ 3:
#   for i in range(1, 51):
#       total += i
# EJ 4:
#   while n >= 1:
#       print(n)
#       ultimo = n
#       n -= 1
# EJ 5:
#   for i in range(1, 101):
#       if i % 7 == 0:
#           multiplos7 += 1
# EJ 6:
#   for i in range(1, 21):
#       if i % 3 == 0 and i % 5 == 0:
#           print("FizzBuzz")
#       elif i % 3 == 0:
#           print("Fizz")
#       elif i % 5 == 0:
#           print("Buzz")
#       else:
#           print(i)
# EJ 7:
#   for i in range(1, 101):
#       if i % 7 == 0 and i % 11 == 0:
#           encontrado = i
#           break
# EJ 8:
#   for i in range(1, 31):
#       if i % 4 == 0:
#           continue
#       suma += i
# EJ 9:
#   for i in range(1, 6):
#       print("*" * i)
# EJ 10:
#   intentos = 0
#   while True:
#       intento = int(input("Adivina: "))
#       intentos += 1
#       if intento == secreto:
#           print(f"¡Acertaste en {intentos} intentos!")
#           break
#       elif intento < secreto:
#           print("El secreto es MAYOR")
#       else:
#           print("El secreto es menor")
