# %% [markdown]
# # Lección 6 · Práctica: Listas y tuplas
#
# Teoría: [README](https://github.com/GeckCore/VScode/blob/main/leccion06-listas-tuplas/README.md)

# %%
# Calentamiento: índices y slicing
letras = ["a", "b", "c", "d", "e", "f"]
print(letras[0], letras[-1])
print(letras[1:4])
print(letras[::-1])

# %% [markdown]
# ### Ejercicio 1 · Acceso
#
# Sin usar `len()` en los índices: guarda el primer elemento en `primero` y el último en `ultimo`.

# %%
# === EJERCICIO 1 ===
colores = ["rojo", "verde", "azul", "amarillo"]
primero = None
ultimo = None

assert primero == "rojo" and ultimo == "amarillo"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Slicing
#
# Extrae con slicing la sublista `[30, 40, 50]`.

# %%
# === EJERCICIO 2 ===
nums = [10, 20, 30, 40, 50, 60]
trozos = None

assert trozos == [30, 40, 50], f"Salió {trozos}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Métodos
#
# Haz estas tres operaciones en orden sobre `tareas`: añade `"estudiar"` al final, elimina `"dormir"`, y ordena la lista alfabéticamente.

# %%
# === EJERCICIO 3 ===
tareas = ["dormir", "comer", "jugar"]
# ← tus 3 líneas aquí



assert tareas == ["comer", "estudiar", "jugar"], f"Salió {tareas}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · Recorrer y sumar
#
# Suma los elementos de `numeros` **con un bucle for** (sin usar `sum()`).

# %%
# === EJERCICIO 4 ===
numeros = [4, 8, 15, 16, 23, 42]
total = 0
# ← tu bucle aquí

assert total == 108
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · Filtrar con bucle
#
# Construye la lista `largos` con las palabras de `palabras` que tengan más de 4 letras.

# %%
# === EJERCICIO 5 ===
palabras = ["sol", "montaña", "mar", "universidad", "luz", "playa"]
largos = []
# ← tu bucle aquí

assert largos == ["montaña", "universidad", "playa"], f"Salió {largos}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 6 · Comprensión
#
# Reescribe el ejercicio 5 en una sola línea con una list comprehension.

# %%
# === EJERCICIO 6 ===
palabras = ["sol", "montaña", "mar", "universidad", "luz", "playa"]
largos2 = None  # ← [p for p in palabras if ...]

assert largos2 == ["montaña", "universidad", "playa"]
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 7 · Comprensión transformadora
#
# Crea `cuadrados_impares`: los cuadrados de los números impares del 1 al 15.

# %%
# === EJERCICIO 7 ===
cuadrados_impares = None

assert cuadrados_impares == [1, 9, 25, 49, 81, 121, 169, 225]
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · La trampa de las referencias
#
# `equipo_b` debería ser una **copia** de `equipo_a` a la que se añade `"Delia"`, sin que `equipo_a` cambie. Ahora mismo está mal. Corrígelo.

# %%
# === EJERCICIO 8 ===
equipo_a = ["Ana", "Bruno"]
equipo_b = equipo_a  # ← aquí está el bug
equipo_b.append("Delia")

assert equipo_a == ["Ana", "Bruno"], f"equipo_a cambió: {equipo_a}. Usa .copy()"
assert equipo_b == ["Ana", "Bruno", "Delia"]
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 9 · Tuplas y desempaquetado
#
# Escribe una función `estadisticas(nums)` que devuelva una tupla `(minimo, maximo, media)`. Luego desempaquétala en tres variables.

# %%
# === EJERCICIO 9 ===


lo, hi, media = estadisticas([2, 4, 6])
assert (lo, hi, media) == (2, 6, 4.0)
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 10 · Reto: ranking
#
# Tienes una lista de tuplas `(nombre, puntos)`. Usa `sorted()` con el parámetro `key` para ordenarla de mayor a menor puntos. Pista: `key=lambda x: x[1]` ordena por el segundo elemento; `reverse=True` invierte el orden.

# %%
# === EJERCICIO 10 ===
jugadores = [("Ana", 50), ("Bruno", 80), ("Clara", 65)]
ranking = None

assert ranking == [("Bruno", 80), ("Clara", 65), ("Ana", 50)], f"Salió {ranking}"
print("✅ ¡Correcto!")

# %% [markdown]
# ---
# ## 🔑 Soluciones

# %%
# SOLUCIONES LECCIÓN 6
# EJ 1: primero = colores[0] ; ultimo = colores[-1]
# EJ 2: trozos = nums[2:5]
# EJ 3: tareas.append("estudiar") ; tareas.remove("dormir") ; tareas.sort()
# EJ 4: for n in numeros: total += n
# EJ 5: for p in palabras:
#           if len(p) > 4:
#               largos.append(p)
# EJ 6: largos2 = [p for p in palabras if len(p) > 4]
# EJ 7: cuadrados_impares = [n**2 for n in range(1, 16) if n % 2 == 1]
# EJ 8: equipo_b = equipo_a.copy()
# EJ 9:
#   def estadisticas(nums):
#       return min(nums), max(nums), sum(nums) / len(nums)
# EJ 10: ranking = sorted(jugadores, key=lambda x: x[1], reverse=True)
