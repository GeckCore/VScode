# %% [markdown]
# # Lección 7 · Práctica: Diccionarios y conjuntos
#
# Teoría: [README](https://github.com/GeckCore/VScode/blob/main/leccion07-diccionarios-conjuntos/README.md)

# %%
# Calentamiento
persona = {"nombre": "Ana", "edad": 18}
print(persona["nombre"])
persona["ciudad"] = "Las Palmas"   # añadir
print(persona.get("telefono", "no tiene"))
for clave, valor in persona.items():
    print(clave, "->", valor)

# %% [markdown]
# ### Ejercicio 1 · Crear y acceder
#
# Crea un diccionario `videojuego` con claves `"titulo"`, `"año"` y `"genero"` de un juego que te guste.

# %%
# === EJERCICIO 1 ===
videojuego = None

assert isinstance(videojuego, dict) and "titulo" in videojuego and "año" in videojuego and "genero" in videojuego
print(f"{videojuego['titulo']} ({videojuego['año']}) — {videojuego['genero']}")
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 2 · Acceso seguro
#
# Sin usar `if`, obtén el valor de `"oro"` del inventario, o `0` si no existe. Usa `.get()`.

# %%
# === EJERCICIO 2 ===
inventario = {"espada": 1, "pociones": 3}
oro = None

assert oro == 0, f"Salió {oro}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 3 · Patrón contador
#
# Cuenta cuántas veces aparece cada palabra en `texto` y guárdalo en el diccionario `frecuencias`.

# %%
# === EJERCICIO 3 ===
texto = ["gato", "perro", "gato", "pez", "gato", "perro"]
frecuencias = {}
# ← tu bucle aquí

assert frecuencias == {"gato": 3, "perro": 2, "pez": 1}, f"Salió {frecuencias}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 4 · El más votado
#
# Recorre el diccionario `votos` y encuentra qué candidato tiene más votos. Guárdalo en `ganador`.

# %%
# === EJERCICIO 4 ===
votos = {"ana": 12, "luis": 19, "bea": 7}
ganador = None
# ← recorre con .items() comparando valores

assert ganador == "luis", f"Salió {ganador}"
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 5 · Invertir un diccionario
#
# Construye `invertido` donde las claves sean los valores de `original` y viceversa.

# %%
# === EJERCICIO 5 ===
original = {"a": 1, "b": 2, "c": 3}
invertido = {}
# ← tu bucle aquí

assert invertido == {1: "a", 2: "b", 3: "c"}
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 6 · Anidados
#
# Del diccionario `tienda`, extrae el precio del segundo producto de la categoría `"frutas"`.

# %%
# === EJERCICIO 6 ===
tienda = {
    "frutas": [{"nombre": "plátano", "precio": 1.2}, {"nombre": "mango", "precio": 2.5}],
    "bebidas": [{"nombre": "agua", "precio": 0.5}]
}
precio_mango = None

assert precio_mango == 2.5
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 7 · Sin duplicados
#
# Convierte la lista `lista` en `sin_repetir`, una lista sin duplicados. Pista: pasa por un `set`. (El orden no importa, el test lo ordena.)

# %%
# === EJERCICIO 7 ===
lista = [5, 3, 5, 1, 3, 1, 9]
sin_repetir = None

assert sorted(sin_repetir) == [1, 3, 5, 9]
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 8 · Operaciones de conjuntos
#
# Dos grupos de amigos van al cine. Calcula: quiénes van en total (`todos`), quiénes están en ambos grupos (`en_ambos`) y quiénes solo están en el grupo a (`solo_a`).

# %%
# === EJERCICIO 8 ===
grupo_a = {"Ana", "Bruno", "Clara", "David"}
grupo_b = {"Clara", "David", "Elena"}
todos = None
en_ambos = None
solo_a = None

assert todos == {"Ana", "Bruno", "Clara", "David", "Elena"}
assert en_ambos == {"Clara", "David"}
assert solo_a == {"Ana", "Bruno"}
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 9 · Dict comprehension
#
# Crea con una sola línea (comprensión de diccionario) el diccionario `{n: n**2}` para n del 1 al 5.

# %%
# === EJERCICIO 9 ===
cuadrados = None

assert cuadrados == {1: 1, 2: 4, 3: 9, 4: 16, 5: 25}
print("✅ ¡Correcto!")

# %% [markdown]
# ### Ejercicio 10 · Reto: agenda telefónica
#
# Crea un programa con un bucle que permita al usuario: (a) añadir contacto, (b) buscar contacto, (c) salir. Guarda todo en un diccionario. Prueba a añadir 2-3 contactos y buscarlos.

# %%
# === EJERCICIO 10 ===
# Escribe tu agenda aquí:

# %% [markdown]
# ---
# ## 🔑 Soluciones

# %%
# SOLUCIONES LECCIÓN 7
# EJ 2: oro = inventario.get("oro", 0)
# EJ 3: for palabra in texto:
#           frecuencias[palabra] = frecuencias.get(palabra, 0) + 1
# EJ 4:
#   max_votos = -1
#   for nombre, n in votos.items():
#       if n > max_votos:
#           max_votos = n
#           ganador = nombre
# EJ 5: for clave, valor in original.items():
#           invertido[valor] = clave
# EJ 6: precio_mango = tienda["frutas"][1]["precio"]
# EJ 7: sin_repetir = list(set(lista))
# EJ 8: todos = grupo_a | grupo_b ; en_ambos = grupo_a & grupo_b ; solo_a = grupo_a - grupo_b
# EJ 9: cuadrados = {n: n**2 for n in range(1, 6)}
# EJ 10:
#   agenda = {}
#   while True:
#       op = input("(a)ñadir (b)uscar (c)salir: ")
#       if op == "c":
#           break
#       elif op == "a":
#           nombre = input("Nombre: ")
#           agenda[nombre] = input("Teléfono: ")
#       elif op == "b":
#           nombre = input("¿Quién? ")
#           print(agenda.get(nombre, "No está en la agenda"))
